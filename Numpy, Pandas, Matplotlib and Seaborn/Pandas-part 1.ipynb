# %% [markdown]
# # Kaggle - Pandas

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## 1.Creating, Reading and Writing

# %% [markdown]
# ### Creating data ----> DataFrame and Series

# %% [markdown]
# ### DataFrame

# %%
pd.DataFrame({'Yes':[50,21],'No':[131,2]})
# Out:
#    Yes   No
# 0   50  131
# 1   21    2

# %%
pd.DataFrame({'Bob':['I liked it.','It was awful.'],'Sue':['Pretty good.','Bland.']},
            index=['Product A','Product B'])
# Out:
#                      Bob           Sue
# Product A    I liked it.  Pretty good.
# Product B  It was awful.        Bland.

# %% [markdown]
# ### Series

# %%
pd.Series([1,2,3,4,5])
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
pd.Series([35,45,55],
         index=['2015','2016','2017'],name='Product A')
# Out:
# 2015    35
# 2016    45
# 2017    55
# Name: Product A, dtype: int64

# %% [markdown]
# ### Reading data files

# %%
wine_reviews = pd.read_csv("winemag-data-130k-v2.csv",index_col=0)

# %%
wine_reviews.shape
# Out:
# (129971, 13)

# %%
wine_reviews.sample(5)
# Out:
#       country                                        description  \
# 17031      US  Very tight yellow-pear-skin aromas meet with l...
# 57484   Italy  This forward wine opens with funky aromas of g...
# 50707   Italy  Aromas of mature dark berry, baking spice, pip...
# 8948   France  Powerful and concentrated, this has a dark red...
# 99572   Italy  Decima Aurea is a refined and elegant expressi...
#
#                            designation  points  price    province  \
# 17031             Bien Nacido Vineyard      90   22.0  California
# 57484                Rio Sordo Riserva      86   60.0    Piedmont
# 50707  del Comune di Serralunga d'Alba      93   49.0    Piedmont
# 8948                               NaN      89   16.0  Beaujolais
# 99572                     Decima Aurea      91   52.0      Veneto
#
#                   region_1       region_2    taster_name  \
# 17031   Santa Maria Valley  Central Coast  Matt Kettmann
# 57484           Barbaresco            NaN  Kerin O’Keefe
# ...

# %%
wine_reviews.head()
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# ...

# %% [markdown]
# #### df = pd.read_csv('input.txt', delimiter=' ')
# #### df.to_csv('output.csv', index=False)
# #### print("Conversion completed.")
# #### Here animals is a dataframe.
# #### "to_csv" is a function

# %% [markdown]
# ## 2.Indexing, Selecting & Assigning

# %%
wine_reviews.country
# Out:
# 0            Italy
# 1         Portugal
# 2               US
# 3               US
# 4               US
#             ...
# 129966     Germany
# 129967          US
# 129968      France
# 129969      France
# 129970      France
# Name: country, Length: 129971, dtype: object

# %%
c=wine_reviews['country']
c
# Out:
# 0            Italy
# 1         Portugal
# 2               US
# 3               US
# 4               US
#             ...
# 129966     Germany
# 129967          US
# 129968      France
# 129969      France
# 129970      France
# Name: country, Length: 129971, dtype: object

# %%
type(c)
# Out:
# pandas.core.series.Series

# %%
wine_reviews['country'][4]
# Out:
# 'US'

# %%
wine_reviews.at[4, 'country']
# Out:
# 'US'

# %%
wine_reviews.points.first_valid_index()
# Out:
# 0

# %% [markdown]
# ### Indexing in pandas

# %%
wine_reviews.iloc[0]
# Out:
# country                                                              Italy
# description              Aromas include tropical fruit, broom, brimston...
# designation                                                   Vulkà Bianco
# points                                                                  87
# price                                                                  NaN
# province                                                 Sicily & Sardinia
# region_1                                                              Etna
# region_2                                                               NaN
# taster_name                                                  Kerin O’Keefe
# taster_twitter_handle                                         @kerinokeefe
# title                                    Nicosia 2013 Vulkà Bianco  (Etna)
# variety                                                        White Blend
# ...

# %%
wine_reviews.iloc[:,0]
# Out:
# 0            Italy
# 1         Portugal
# 2               US
# 3               US
# 4               US
#             ...
# 129966     Germany
# 129967          US
# 129968      France
# 129969      France
# 129970      France
# Name: country, Length: 129971, dtype: object

# %%
wine_reviews.iloc[:3,0]
# Out:
# 0       Italy
# 1    Portugal
# 2          US
# Name: country, dtype: object

# %%
wine_reviews.iloc[:3,0:4]
# Out:
#     country                                        description   designation  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...  Vulkà Bianco
# 1  Portugal  This is ripe and fruity, a wine that is smooth...      Avidagos
# 2        US  Tart and snappy, the flavors of lime flesh and...           NaN
#
#    points
# 0      87
# 1      87
# 2      87

# %%
wine_reviews.iloc[[0,1,2,3,4],0]
# Out:
# 0       Italy
# 1    Portugal
# 2          US
# 3          US
# 4          US
# Name: country, dtype: object

# %%
wine_reviews.iloc[-5:]
# Out:
#         country                                        description  \
# 129966  Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967       US  Citation is given as much as a decade of bottl...
# 129968   France  Well-drained gravel soil gives this wine its c...
# 129969   France  A dry style of Pinot Gris, this is crisp with ...
# 129970   France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price province  \
# 129966  Brauneberger Juffer-Sonnenuhr Spätlese      90   28.0    Mosel
# 129967                                     NaN      90   75.0   Oregon
# 129968                                   Kritt      90   30.0   Alsace
# 129969                                     NaN      90   32.0   Alsace
# 129970           Lieu-dit Harth Cuvée Caroline      90   21.0   Alsace
#
#        region_1      region_2         taster_name taster_twitter_handle  \
# ...

# %% [markdown]
# ### Label-based selection

# %%
wine_reviews.loc[0,'country']
# Out:
# 'Italy'

# %%
wine_reviews.loc[0:3,['points','price']]
# Out:
#    points  price
# 0      87    NaN
# 1      87   15.0
# 2      87   14.0
# 3      87   13.0

# %% [markdown]
# ### Manipulating the index

# %%
wine_reviews.set_index("price")
# Out:
#         country                                        description  \
# price
# NaN       Italy  Aromas include tropical fruit, broom, brimston...
# 15.0   Portugal  This is ripe and fruity, a wine that is smooth...
# 14.0         US  Tart and snappy, the flavors of lime flesh and...
# 13.0         US  Pineapple rind, lemon pith and orange blossom ...
# 65.0         US  Much like the regular bottling from 2012, this...
# ...         ...                                                ...
# 28.0    Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 75.0         US  Citation is given as much as a decade of bottl...
# 30.0     France  Well-drained gravel soil gives this wine its c...
# 32.0     France  A dry style of Pinot Gris, this is crisp with ...
# 21.0     France  Big, rich and off-dry, this is powered by inte...
#
#                                   designation  points           province  \
# price
# ...

# %% [markdown]
# ### Conditional selection

# %%
wine_reviews.country == 'Italy'
# Out:
# 0          True
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 129966    False
# 129967    False
# 129968    False
# 129969    False
# 129970    False
# Name: country, Length: 129971, dtype: bool

# %%
wine_reviews.loc[wine_reviews.country == 'Italy']
# Out:
#        country                                        description  \
# 0        Italy  Aromas include tropical fruit, broom, brimston...
# 6        Italy  Here's a bright, informal red that opens with ...
# 13       Italy  This is dominated by oak and oak-driven aromas...
# 22       Italy  Delicate aromas recall white flower and citrus...
# 24       Italy  Aromas of prune, blackcurrant, toast and oak c...
# ...        ...                                                ...
# 129929   Italy  This luminous sparkler has a sweet, fruit-forw...
# 129943   Italy  A blend of Nero d'Avola and Syrah, this convey...
# 129947   Italy  A blend of 65% Cabernet Sauvignon, 30% Merlot ...
# 129961   Italy  Intense aromas of wild cherry, baking spice, t...
# 129962   Italy  Blackberry, cassis, grilled herb and toasted a...
#
#                       designation  points  price           province  \
# 0                    Vulkà Bianco      87    NaN  Sicily & Sardinia
# ...

# %%
wine_reviews.loc[(wine_reviews.country == 'Italy') & (wine_reviews.price <= 5)]
# Out:
#        country                                        description designation  \
# 3167     Italy  Packaged in a pocket-friendly 187-ml bottle, t...        Mini
# 102853   Italy  Definitely not Zinfandel-like, despite its Pri...         NaN
# 102859   Italy  Terrale translates as “product of the earth,” ...      Bianco
# 102861   Italy  A thin peach nose is the initial impression, f...         NaN
#
#         points  price           province        region_1 region_2 taster_name  \
# 3167        86    5.0             Veneto        Prosecco      NaN         NaN
# 102853      83    5.0     Southern Italy          Puglia      NaN         NaN
# 102859      82    5.0  Sicily & Sardinia         Sicilia      NaN         NaN
# 102861      81    5.0           Lombardy  Oltrepò Pavese      NaN         NaN
#
#        taster_twitter_handle                                        title  \
# 3167                     NaN             Anna Spinato NV Mini  (Prosecco)
# ...

# %%
wine_reviews.loc[(wine_reviews.country.isin(['Italy'])) & (wine_reviews.price <=5)]
# Out:
#        country                                        description designation  \
# 3167     Italy  Packaged in a pocket-friendly 187-ml bottle, t...        Mini
# 102853   Italy  Definitely not Zinfandel-like, despite its Pri...         NaN
# 102859   Italy  Terrale translates as “product of the earth,” ...      Bianco
# 102861   Italy  A thin peach nose is the initial impression, f...         NaN
#
#         points  price           province        region_1 region_2 taster_name  \
# 3167        86    5.0             Veneto        Prosecco      NaN         NaN
# 102853      83    5.0     Southern Italy          Puglia      NaN         NaN
# 102859      82    5.0  Sicily & Sardinia         Sicilia      NaN         NaN
# 102861      81    5.0           Lombardy  Oltrepò Pavese      NaN         NaN
#
#        taster_twitter_handle                                        title  \
# 3167                     NaN             Anna Spinato NV Mini  (Prosecco)
# ...

# %%
wine_reviews.loc[wine_reviews.price.isnull()]
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 13         Italy  This is dominated by oak and oak-driven aromas...
# 30        France  Red cherry fruit comes laced with light tannin...
# 31         Italy  Merlot and Nero d'Avola form the base for this...
# 32         Italy  Part of the extended Calanìca series, this Gri...
# ...          ...                                                ...
# 129844     Italy  Doga delle Clavule is a neutral, mineral-drive...
# 129860  Portugal  This rich wine has a firm structure as well as...
# 129863  Portugal  This mature wine that has 50% Touriga Nacional...
# 129893     Italy  Aromas of passion fruit, hay and a vegetal not...
# 129964    France  Initially quite muted, this wine slowly develo...
#
#                          designation  points  price           province  \
# 0                       Vulkà Bianco      87    NaN  Sicily & Sardinia
# ...

# %%
wine_reviews.loc[wine_reviews.price.notnull()]
# Out:
#          country                                        description  \
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 4             US  Much like the regular bottling from 2012, this...
# 5          Spain  Blackberry and raspberry aromas show a typical...
# ...          ...                                                ...
# 129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967        US  Citation is given as much as a decade of bottl...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price        province  \
# ...

# %% [markdown]
# ### Assigning data

# %%
wine_reviews['critics']='everyone'
wine_reviews
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 4             US  Much like the regular bottling from 2012, this...
# ...          ...                                                ...
# 129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967        US  Citation is given as much as a decade of bottl...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price  \
# 0                                 Vulkà Bianco      87    NaN
# ...

# %%
wine_reviews['index_backwards']=range(len(wine_reviews),0,-1)
wine_reviews
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 4             US  Much like the regular bottling from 2012, this...
# ...          ...                                                ...
# 129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967        US  Citation is given as much as a decade of bottl...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price  \
# 0                                 Vulkà Bianco      87    NaN
# ...

# %% [markdown]
# #### a.Select the records with index labels 1, 2, 3, 5, and 8, assigning the result to the variable.
# #### sample_reviews
# #### In other words, generate the following DataFrame:

# %%
sample_reviews = wine_reviews.loc[[1,2,3,5,8],:]
sample_reviews
# Out:
#     country                                        description  \
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 5     Spain  Blackberry and raspberry aromas show a typical...
# 8   Germany  Savory dried thyme notes accent sunnier flavor...
#
#             designation  points  price        province             region_1  \
# 1              Avidagos      87   15.0           Douro                  NaN
# 2                   NaN      87   14.0          Oregon    Willamette Valley
# 3  Reserve Late Harvest      87   13.0        Michigan  Lake Michigan Shore
# 5          Ars In Vitro      87   15.0  Northern Spain              Navarra
# 8                 Shine      87   12.0     Rheinhessen                  NaN
#
#             region_2         taster_name taster_twitter_handle  \
# ...

# %% [markdown]
# #### b.Create a DataFrame top_oceania_wines containing all reviews with at least 95 points (out of 100) for wines from Australia or New Zealand.

# %%
top_oceania_wines = wine_reviews.loc[
    (wine_reviews.country.isin(['Australia','New Zealand']))
    & (wine_reviews.points >= 95)
]
top_oceania_wines
# Out:
#             country                                        description  \
# 345       Australia  This wine contains some material over 100 year...
# 346       Australia  This deep brown wine smells like a damp, mossy...
# 348       Australia  Deep mahogany. Dried fig and black tea on the ...
# 349       Australia  RunRig is always complex, and the 2012 doesn't...
# 356       Australia  Dusty, firm, powerful: just a few apt descript...
# 360       Australia  Bacon and tapenade elements merge easily on th...
# 365       Australia  The Taylor family selected Clare Valley for it...
# 14354     Australia  This wine's concentrated dark fruit shows in t...
# 16538     Australia  Rich, dense and intense, this is a big, muscul...
# 28573     Australia  Astralis has become one of Australia's top col...
# 34502     Australia  This prodigious wine showcases Barossa's abili...
# 34506     Australia  If Standish's Relic is the feminine side of Sh...
# ...

# %% [markdown]
# ## 3. Summary Functions and Maps

# %% [markdown]
# ### Summary functions

# %%
wine_reviews.points.describe()
# Out:
# count    129971.000000
# mean         88.447138
# std           3.039730
# min          80.000000
# 25%          86.000000
# 50%          88.000000
# 75%          91.000000
# max         100.000000
# Name: points, dtype: float64

# %%
wine_reviews.taster_name.describe()
# Out:
# count         103727
# unique            19
# top       Roger Voss
# freq           25514
# Name: taster_name, dtype: object

# %%
wine_reviews.points.mean()
# Out:
# 88.44713820775404

# %%
wine_reviews.points.unique()
# Out:
# array([ 87,  86,  85,  88,  92,  91,  90,  89,  83,  82,  81,  80, 100,
#         98,  97,  96,  95,  93,  94,  84,  99], dtype=int64)

# %%
wine_reviews.country.value_counts()
# Out:
# US                        54504
# France                    22093
# Italy                     19540
# Spain                      6645
# Portugal                   5691
# Chile                      4472
# Argentina                  3800
# Austria                    3345
# Australia                  2329
# Germany                    2165
# New Zealand                1419
# South Africa               1401
# Israel                      505
# Greece                      466
# Canada                      257
# Hungary                     146
# Bulgaria                    141
# Romania                     120
# Uruguay                     109
# Turkey                       90
# Slovenia                     87
# Georgia                      86
# England                      74
# Croatia                      73
# Mexico                       70
# Moldova                      59
# Brazil                       52
# Lebanon                      35
# Morocco                      28
# ...

# %% [markdown]
# ### Maps

# %%
wine_reviews_points_mean = wine_reviews.points.mean()
wine_reviews.points.map(lambda p: p - wine_reviews_points_mean)
# Out:
# 0        -1.447138
# 1        -1.447138
# 2        -1.447138
# 3        -1.447138
# 4        -1.447138
#             ...
# 129966    1.552862
# 129967    1.552862
# 129968    1.552862
# 129969    1.552862
# 129970    1.552862
# Name: points, Length: 129971, dtype: float64

# %%
def remean_points(row):
    row.points = row.points - wine_reviews_points_mean
    return row
wine_reviews.apply(remean_points, axis = 'columns')
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 4             US  Much like the regular bottling from 2012, this...
# ...          ...                                                ...
# 129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967        US  Citation is given as much as a decade of bottl...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation    points  price  \
# 0                                 Vulkà Bianco -1.447138    NaN
# ...

# %%
wine_reviews.head(1)
# Out:
#   country                                        description   designation  \
# 0   Italy  Aromas include tropical fruit, broom, brimston...  Vulkà Bianco
#
#    points  price           province region_1 region_2    taster_name  \
# 0      87    NaN  Sicily & Sardinia     Etna      NaN  Kerin O’Keefe
#
#   taster_twitter_handle                              title      variety  \
# 0          @kerinokeefe  Nicosia 2013 Vulkà Bianco  (Etna)  White Blend
#
#     winery   critics  index_backwards
# 0  Nicosia  everyone           129971

# %%
wine_reviews_points_mean = wine_reviews.points.mean()
wine_reviews.points - wine_reviews_points_mean
# Out:
# 0        -1.447138
# 1        -1.447138
# 2        -1.447138
# 3        -1.447138
# 4        -1.447138
#             ...
# 129966    1.552862
# 129967    1.552862
# 129968    1.552862
# 129969    1.552862
# 129970    1.552862
# Name: points, Length: 129971, dtype: float64

# %%
wine_reviews.country + " - " + wine_reviews.region_1
# Out:
# 0                     Italy - Etna
# 1                              NaN
# 2           US - Willamette Valley
# 3         US - Lake Michigan Shore
# 4           US - Willamette Valley
#                     ...
# 129966                         NaN
# 129967                 US - Oregon
# 129968             France - Alsace
# 129969             France - Alsace
# 129970             France - Alsace
# Length: 129971, dtype: object

# %% [markdown]
# #### a.What is the median of the `points` column in the `reviews` DataFrame?

# %%
median_points = wine_reviews.points.median()
median_points
# Out:
# 88.0

# %% [markdown]
# #### b.What countries are represented in the dataset? (Your answer should not include any duplicates.)

# %%
countries = wine_reviews.country.unique()
countries
# Out:
# array(['Italy', 'Portugal', 'US', 'Spain', 'France', 'Germany',
#        'Argentina', 'Chile', 'Australia', 'Austria', 'South Africa',
#        'New Zealand', 'Israel', 'Hungary', 'Greece', 'Romania', 'Mexico',
#        'Canada', nan, 'Turkey', 'Czech Republic', 'Slovenia',
#        'Luxembourg', 'Croatia', 'Georgia', 'Uruguay', 'England',
#        'Lebanon', 'Serbia', 'Brazil', 'Moldova', 'Morocco', 'Peru',
#        'India', 'Bulgaria', 'Cyprus', 'Armenia', 'Switzerland',
#        'Bosnia and Herzegovina', 'Ukraine', 'Slovakia', 'Macedonia',
#        'China', 'Egypt'], dtype=object)

# %% [markdown]
# #### c.How often does each country appear in the dataset? Create a Series `reviews_per_country` mapping countries to the count of reviews of wines from that country.

# %%
reviews_per_country = wine_reviews.country.value_counts()
reviews_per_country
# Out:
# US                        54504
# France                    22093
# Italy                     19540
# Spain                      6645
# Portugal                   5691
# Chile                      4472
# Argentina                  3800
# Austria                    3345
# Australia                  2329
# Germany                    2165
# New Zealand                1419
# South Africa               1401
# Israel                      505
# Greece                      466
# Canada                      257
# Hungary                     146
# Bulgaria                    141
# Romania                     120
# Uruguay                     109
# Turkey                       90
# Slovenia                     87
# Georgia                      86
# England                      74
# Croatia                      73
# Mexico                       70
# Moldova                      59
# Brazil                       52
# Lebanon                      35
# Morocco                      28
# ...

# %% [markdown]
# #### d.Create variable `centered_price` containing a version of the `price` column with the mean price subtracted.
# #### (Note: this 'centering' transformation is a common preprocessing step before applying various machine learning algorithms.)

# %%
centered_price = wine_reviews.price - wine_reviews.price.mean()
centered_price
# Out:
# 0               NaN
# 1        -20.363389
# 2        -21.363389
# 3        -22.363389
# 4         29.636611
#             ...
# 129966    -7.363389
# 129967    39.636611
# 129968    -5.363389
# 129969    -3.363389
# 129970   -14.363389
# Name: price, Length: 129971, dtype: float64

# %% [markdown]
# #### e.I'm an economical wine buyer. Which wine is the "best bargain"? Create a variable `bargain_wine` with the title of the wine with the highest points-to-price ratio in the dataset.

# %%
bargain_idx = (wine_reviews.points / wine_reviews.price).idxmax()
bargain_wine = wine_reviews.loc[bargain_idx, 'title']

# %% [markdown]
# #### f.There are only so many words you can use when describing a bottle of wine. Is a wine more likely to be "tropical" or "fruity"? Create a Series `descriptor_counts` counting how many times each of these two words appears in the `description` column in the dataset. (For simplicity, let's ignore the capitalized versions of these words.)

# %%
descriptor = ['tropical', 'fruity']
n_trop = wine_reviews.description.map(lambda desc: 'tropical' in desc).sum()
n_fruit = wine_reviews.description.map(lambda desc: 'fruity' in desc).sum()
descriptor_counts = pd.Series([n_trop, n_fruit], index = descriptor, name = 'Descriptor')

# %% [markdown]
# #### g.We'd like to host these wine reviews on our website, but a rating system ranging from 80 to 100 points is too hard to understand - we'd like to translate them into simple star ratings. A score of 95 or higher counts as 3 stars, a score of at least 85 but less than 95 is 2 stars. Any other score is 1 star.
# #### Also, the Canadian Vintners Association bought a lot of ads on the site, so any wines from Canada should automatically get 3 stars, regardless of points.
# #### Create a series `star_ratings` with the number of stars corresponding to each review in the dataset.

# %%
def stars(row):
    if row.country == 'Canada':
        return 3
    elif row.points >= 95:
        return 3
    elif row.points >= 85:
        return 2
    else:
        return 1
star_ratings = wine_reviews.apply(stars, axis = 'columns')

# %% [markdown]
# ## 4.Grouping and Sorting

# %% [markdown]
# ### Groupwise analysis

# %%
wine_reviews.groupby('points').points.count()
# Out:
# points
# 80       397
# 81       692
# 82      1836
# 83      3025
# 84      6480
# 85      9530
# 86     12600
# 87     16933
# 88     17207
# 89     12226
# 90     15410
# 91     11359
# 92      9613
# 93      6489
# 94      3758
# 95      1535
# 96       523
# 97       229
# 98        77
# 99        33
# 100       19
# Name: points, dtype: int64

# %%
pd.set_option("display.max_rows", 6)

# %%
wine_reviews['points'].value_counts()
# Out:
# 88     17207
# 87     16933
# 90     15410
# 86     12600
# 89     12226
# 91     11359
# 92      9613
# 85      9530
# 93      6489
# 84      6480
# 94      3758
# 83      3025
# 82      1836
# 95      1535
# 81       692
# 96       523
# 80       397
# 97       229
# 98        77
# 99        33
# 100       19
# Name: points, dtype: int64

# %%
wine_reviews.groupby('points').price.min()
# Out:
# points
# 80      5.0
# 81      5.0
# 82      4.0
# 83      4.0
# 84      4.0
# 85      4.0
# 86      4.0
# 87      5.0
# 88      6.0
# 89      7.0
# 90      8.0
# 91      7.0
# 92     11.0
# 93     12.0
# 94     13.0
# 95     20.0
# 96     20.0
# 97     35.0
# 98     50.0
# 99     44.0
# 100    80.0
# Name: price, dtype: float64

# %%
wine_reviews.groupby('winery').apply(lambda df : df.title.iloc[0])
# Out:
# winery
# 1+1=3                                     1+1=3 NV Rosé Sparkling (Cava)
# 10 Knots                            10 Knots 2010 Viognier (Paso Robles)
# 100 Percent Wine              100 Percent Wine 2015 Moscato (California)
#                                              ...
# Ökonomierat Rebholz    Ökonomierat Rebholz 2007 Von Rotliegenden Spät...
# àMaurice               àMaurice 2013 Fred Estate Syrah (Walla Walla V...
# Štoka                                    Štoka 2009 Izbrani Teran (Kras)
# Length: 16757, dtype: object

# %%
wine_reviews.groupby(['country']).price.agg([len, min, max])
# Out:
#              len   min     max
# country
# Argentina   3800   4.0   230.0
# Armenia        2  14.0    15.0
# Australia   2329   5.0   850.0
# ...          ...   ...     ...
# US         54504   4.0  2013.0
# Ukraine       14   6.0    13.0
# Uruguay      109  10.0   130.0
#
# [43 rows x 3 columns]

# %% [markdown]
# ### Multi-indexes

# %%
countries_reviewed = wine_reviews.groupby(['country', 'province']).description.agg([len])
countries_reviewed
# Out:
#                              len
# country   province
# Argentina Mendoza Province  3264
#           Other              536
# Armenia   Armenia              2
# ...                          ...
# Uruguay   Progreso            11
#           San Jose             3
#           Uruguay             24
#
# [425 rows x 1 columns]

# %%
mi = countries_reviewed.index
type(mi)
# Out:
# pandas.core.indexes.multi.MultiIndex

# %%
countries_reviewed.reset_index()
# Out:
#        country          province   len
# 0    Argentina  Mendoza Province  3264
# 1    Argentina             Other   536
# 2      Armenia           Armenia     2
# ..         ...               ...   ...
# 422    Uruguay          Progreso    11
# 423    Uruguay          San Jose     3
# 424    Uruguay           Uruguay    24
#
# [425 rows x 3 columns]

# %% [markdown]
# ### Sorting

# %%
countries_reviewed = countries_reviewed.reset_index()
countries_reviewed.sort_values(by='len')
# Out:
#     country               province    len
# 179  Greece  Muscat of Kefallonian      1
# 192  Greece          Sterea Ellada      1
# 194  Greece                 Thraki      1
# ..      ...                    ...    ...
# 118  France               Bordeaux   5941
# 415      US             Washington   8639
# 392      US             California  36247
#
# [425 rows x 3 columns]

# %%
countries_reviewed.sort_values(by = 'len', ascending = False)
# Out:
#           country         province    len
# 392            US       California  36247
# 415            US       Washington   8639
# 118        France         Bordeaux   5941
# ..            ...              ...    ...
# 357  South Africa  Piekenierskloof      1
# 63          Chile          Coelemu      1
# 149        Greece           Beotia      1
#
# [425 rows x 3 columns]

# %%
countries_reviewed.sort_index()
# Out:
#        country          province   len
# 0    Argentina  Mendoza Province  3264
# 1    Argentina             Other   536
# 2      Armenia           Armenia     2
# ..         ...               ...   ...
# 422    Uruguay          Progreso    11
# 423    Uruguay          San Jose     3
# 424    Uruguay           Uruguay    24
#
# [425 rows x 3 columns]

# %%
countries_reviewed.sort_values(by = ['country', 'len'])
# Out:
#        country          province   len
# 1    Argentina             Other   536
# 0    Argentina  Mendoza Province  3264
# 2      Armenia           Armenia     2
# ..         ...               ...   ...
# 420    Uruguay           Juanico    12
# 424    Uruguay           Uruguay    24
# 419    Uruguay         Canelones    43
#
# [425 rows x 3 columns]

# %% [markdown]
# ### a.Who are the most common wine reviewers in the dataset? Create a Series whose index is the taster_twitter_handle category from the dataset, and whose values count how many reviews each person wrote.

# %%
reviews_written = wine_reviews.groupby('taster_twitter_handle').size()

# %%
#or

# %%
reviews_written = wine_reviews.groupby('taster_twitter_handle').size()

# %% [markdown]
# ### b.What is the best wine I can buy for a given amount of money? Create a Series whose index is wine prices and whose values is the maximum number of points a wine costing that much was given in a review. Sort the values by price, ascending (so that 4.0 dollars is at the top and 3300.0 dollars is at the bottom).

# %%
best_rating_per_price = wine_reviews.groupby('price')['points'].max().sort_index()

# %% [markdown]
# ### c.What are the minimum and maximum prices for each variety of wine? Create a DataFrame whose index is the variety category from the dataset and whose values are the min and max values thereof.### 3.

# %%
price_extremes = wine_reviews.groupby('variety').price.agg([min, max])

# %% [markdown]
# ### d.What are the most expensive wine varieties? Create a variable sorted_varieties containing a copy of the dataframe from the previous question where varieties are sorted in descending order based on minimum price, then on maximum price (to break ties).

# %%
sorted_varieties = price_extremes.sort_values(by = ['min', 'max'], ascending = False)

# %% [markdown]
# ### e.Create a Series whose index is reviewers and whose values is the average review score given out by that reviewer. Hint: you will need the taster_name and points columns.

# %%
reviewer_mean_ratings = wine_reviews.groupby('taster_name').points.mean()

# %% [markdown]
# ### f.What combination of countries and varieties are most common? Create a Series whose index is a MultiIndexof {country, variety} pairs. For example, a pinot noir produced in the US should map to {"US", "Pinot Noir"}. Sort the values in the Series in descending order based on wine count.

# %%
country_variety_counts = wine_reviews.groupby(['country', 'variety']).size().sort_values(ascending = False)

# %% [markdown]
# ## 5.Data Types and Missing Values

# %% [markdown]
# #### Dtypes
# #### The data type for a column in a DataFrame or a Series is known as the dtype.

# %%
wine_reviews.price.dtype
# Out:
# dtype('float64')

# %%
wine_reviews.dtypes
# Out:
# country            object
# description        object
# designation        object
#                     ...
# winery             object
# critics            object
# index_backwards     int64
# Length: 15, dtype: object

# %%
wine_reviews.points.astype('float64')
# Out:
# 0         87.0
# 1         87.0
# 2         87.0
#           ...
# 129968    90.0
# 129969    90.0
# 129970    90.0
# Name: points, Length: 129971, dtype: float64

# %%
wine_reviews.index.dtype
# Out:
# dtype('int64')

# %% [markdown]
# ### Missing data

# %%
wine_reviews[pd.isnull(wine_reviews.country)]
# Out:
#        country                                        description  \
# 913        NaN  Amber in color, this wine has aromas of peach ...
# 3131       NaN  Soft, fruity and juicy, this is a pleasant, si...
# 4243       NaN  Violet-red in color, this semisweet wine has a...
# ...        ...                                                ...
# 129408     NaN  El Capricho is one of Uruguay's more consisten...
# 129590     NaN  A blend of 60% Syrah, 30% Cabernet Sauvignon a...
# 129900     NaN  This wine offers a delightful bouquet of black...
#
#                      designation  points  price province region_1 region_2  \
# 913               Asureti Valley      87   30.0      NaN      NaN      NaN
# 3131                    Partager      83    NaN      NaN      NaN      NaN
# 4243    Red Naturally Semi-Sweet      88   18.0      NaN      NaN      NaN
# ...                          ...     ...    ...      ...      ...      ...
# ...

# %%
wine_reviews.region_2.fillna("Unknown")
# Out:
# 0                   Unknown
# 1                   Unknown
# 2         Willamette Valley
#                 ...
# 129968              Unknown
# 129969              Unknown
# 129970              Unknown
# Name: region_2, Length: 129971, dtype: object

# %%
wine_reviews.taster_twitter_handle.replace("kerinokeefe", "@kerino")
# Out:
# 0         @kerinokeefe
# 1           @vossroger
# 2          @paulgwine
#               ...
# 129968      @vossroger
# 129969      @vossroger
# 129970      @vossroger
# Name: taster_twitter_handle, Length: 129971, dtype: object

# %% [markdown]
# ### a.What is the data type of the `points` column in the dataset?

# %%
dtype = wine_reviews.points.dtype

# %% [markdown]
# ### b.Create a Series from entries in the points column, but convert the entries to strings. Hint: strings are str in native Python.

# %%
point_strings = wine_reviews.points.astype(str)

# %% [markdown]
# ### c.Sometimes the price column is null. How many reviews in the dataset are missing a price?

# %%
missing_price_reviews = wine_reviews[wine_reviews.price.isnull()]
n_missing_prices = len(missing_price_reviews)

# %%
#or

# %%
n_missing_prices = wine_reviews.price.isnull().sum()

# %% [markdown]
# ### d.What are the most common wine-producing regions? Create a Series counting the number of times each value occurs in the region_1 field. This field is often missing data, so replace missing values with Unknown. Sort in descending order. Your output should look something like this:
#
# ### Unknown                    21247
# ### Napa Valley                 4480
# ###                           ...
# ### Bardolino Superiore            1
# ### Primitivo del Tarantino        1
# ### Name: region_1, Length: 1230, dtype: int64

# %%
reviews_pr_region = wine_reviews.region_1.fillna('Unknown').value_counts().sort_values(ascending=False)

# %% [markdown]
# ## 6.Renaming and Combining

# %%
wine_reviews.rename(columns ={ 'points': 'score'})
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# ...          ...                                                ...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                           designation  score  price           province  \
# 0                        Vulkà Bianco     87    NaN  Sicily & Sardinia
# 1                            Avidagos     87   15.0              Douro
# 2                                 NaN     87   14.0             Oregon
# ...                               ...    ...    ...                ...
# ...

# %%
wine_reviews.rename(index = {0: 'firstEntry', 1: 'secondEntry'})
# Out:
#               country                                        description  \
# firstEntry      Italy  Aromas include tropical fruit, broom, brimston...
# secondEntry  Portugal  This is ripe and fruity, a wine that is smooth...
# 2                  US  Tart and snappy, the flavors of lime flesh and...
# ...               ...                                                ...
# 129968         France  Well-drained gravel soil gives this wine its c...
# 129969         France  A dry style of Pinot Gris, this is crisp with ...
# 129970         France  Big, rich and off-dry, this is powered by inte...
#
#                                designation  points  price           province  \
# firstEntry                    Vulkà Bianco      87    NaN  Sicily & Sardinia
# secondEntry                       Avidagos      87   15.0              Douro
# 2                                      NaN      87   14.0             Oregon
# ...

# %%
wine_reviews.rename_axis("wines", axis = 'rows').rename_axis("fields", axis = 'columns')
# Out:
# fields   country                                        description  \
# wines
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# ...          ...                                                ...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
# fields                    designation  points  price           province  \
# wines
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# ...                               ...     ...    ...                ...
# ...

# %% [markdown]
# ### Combining

# %%
canadian_youtube = pd.read_csv("CAvideos.csv")
british_youtube = pd.read_csv("GBvideos.csv")
pd.concat([canadian_youtube, british_youtube]).head(1)
# Out:
#       video_id trending_date                                       title  \
# 0  n1WpP7iowLc      17.14.11  Eminem - Walk On Water (Audio) ft. Beyoncé
#
#   channel_title  category_id              publish_time  \
# 0    EminemVEVO           10  2017-11-10T17:00:03.000Z
#
#                                                 tags     views   likes  \
# 0  Eminem|"Walk"|"On"|"Water"|"Aftermath/Shady/In...  17158579  787425
#
#    dislikes  comment_count                                  thumbnail_link  \
# 0     43420         125882  https://i.ytimg.com/vi/n1WpP7iowLc/default.jpg
#
#    comments_disabled  ratings_disabled  video_error_or_removed  \
# 0              False             False                   False
#
#                                          description
# 0  Eminem's new track Walk on Water ft. Beyoncé i...

# %%
canadian_youtube.head(1)
# Out:
#       video_id trending_date                                       title  \
# 0  n1WpP7iowLc      17.14.11  Eminem - Walk On Water (Audio) ft. Beyoncé
#
#   channel_title  category_id              publish_time  \
# 0    EminemVEVO           10  2017-11-10T17:00:03.000Z
#
#                                                 tags     views   likes  \
# 0  Eminem|"Walk"|"On"|"Water"|"Aftermath/Shady/In...  17158579  787425
#
#    dislikes  comment_count                                  thumbnail_link  \
# 0     43420         125882  https://i.ytimg.com/vi/n1WpP7iowLc/default.jpg
#
#    comments_disabled  ratings_disabled  video_error_or_removed  \
# 0              False             False                   False
#
#                                          description
# 0  Eminem's new track Walk on Water ft. Beyoncé i...

# %%
british_youtube.head(1)
# Out:
#       video_id trending_date                                          title  \
# 0  Jw1Y-zhQURU      17.14.11  John Lewis Christmas Ad 2017 - #MozTheMonster
#
#   channel_title  category_id              publish_time  \
# 0    John Lewis           26  2017-11-10T07:38:29.000Z
#
#                                                 tags    views  likes  \
# 0  christmas|"john lewis christmas"|"john lewis"|...  7224515  55681
#
#    dislikes  comment_count                                  thumbnail_link  \
# 0     10247           9479  https://i.ytimg.com/vi/Jw1Y-zhQURU/default.jpg
#
#    comments_disabled  ratings_disabled  video_error_or_removed  \
# 0              False             False                   False
#
#                                          description
# 0  Click here to continue the story and make your...

# %%
left = canadian_youtube.set_index(['title', 'trending_date'])
right = british_youtube.set_index(['title', 'trending_date'])
left.join(right, lsuffix = '_CAN', rsuffix = '_UK')
# Out:
#                                                                  video_id_CAN  \
# title                                              trending_date
# !! THIS VIDEO IS NOTHING BUT PAIN !! | Getting ... 18.04.01       PNn8sECd7io
# #1 Fortnite World Rank - 2,323 Solo Wins!          18.09.03       DvPW66IFhMI
# #1 Fortnite World Rank - 2,330 Solo Wins!          18.10.03       EXEaMjFeiEk
# ...                                                                       ...
# 😲She Is So Nervous But BLOWS The ROOF After Tak... 18.30.04       WttN1Z0XF4k
# 🚨 BREAKING NEWS 🔴 Raja Live all Slot Channels W... 18.07.05       Wt9Gkpmbt44
# 🚨Active Shooter at YouTube Headquarters - LIVE ... 18.04.04       Az72jrKbANA
#
#                                                                                 channel_title_CAN  \
# title                                              trending_date
# !! THIS VIDEO IS NOTHING BUT PAIN !! | Getting ... 18.04.01                            Markiplier
# ...

# %% [markdown]
# ### a.`region_1` and `region_2` are pretty uninformative names for locale columns in the dataset. Create a copy of `reviews` with these columns renamed to `region` and `locale`, respectively.

# %%
renamed = wine_reviews.rename(columns=dict(region_1='region', region_2='locale'))

# %% [markdown]
# ### b.Set the index name in the dataset to `wines`.

# %%
reindexed = wine_reviews.rename_axis('wines', axis='rows')

# %% [markdown]
# ### c.The [Things on Reddit](https://www.kaggle.com/residentmario/things-on-reddit/data) dataset includes product links from a selection of top-ranked forums ("subreddits") on reddit.com. Run the cell below to load a dataframe of products mentioned on the */r/gaming* subreddit and another dataframe for products mentioned on the *r//movies* subreddit.

# %% [markdown]
# #### gaming_products = pd.read_csv("../input/things-on-reddit/top-things/top-things/reddits/g/gaming.csv")
# #### gaming_products['subreddit'] = "r/gaming"
# #### movie_products = pd.read_csv("../input/things-on-reddit/top-things/top-things/reddits/m/movies.csv")
# #### movie_products['subreddit'] = "r/movies"
# #### combined_products = pd.concat([gaming_products, movie_products])

# %% [markdown]
# ### d.The [Powerlifting Database](https://www.kaggle.com/open-powerlifting/powerlifting-database) dataset on Kaggle includes one CSV table for powerlifting meets and a separate one for powerlifting competitors. Run the cell below to load these datasets into dataframes:

# %% [markdown]
# #### powerlifting_meets = pd.read_csv("../input/powerlifting-database/meets.csv")
# #### powerlifting_competitors = pd.read_csv("../input/powerlifting-database/openpowerlifting.csv")
# #### powerlifting_combined = powerlifting_meets.set_index("MeetID").join(powerlifting_competitors.set_index("MeetID"))
